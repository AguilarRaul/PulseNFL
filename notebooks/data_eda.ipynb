# %%
# Importing libraries
import pandas as pd

# %%
# reading data
nfl_data = pd.read_csv('https://raw.githubusercontent.com/rfordatascience/tidytuesday/master/data/2020/2020-02-04/standings.csv')

# %%
# check first few rows
nfl_data.head(3)
# Out:
#            team team_name  year  wins  loss  points_for  points_against  \
# 0         Miami  Dolphins  2000    11     5         323             226
# 1  Indianapolis     Colts  2000    10     6         429             326
# 2      New York      Jets  2000     9     7         321             321
#
#    points_differential  margin_of_victory  strength_of_schedule  \
# 0                   97                6.1                   1.0
# 1                  103                6.4                   1.5
# 2                    0                0.0                   3.5
#
#    simple_rating  offensive_ranking  defensive_ranking     playoffs  \
# 0            7.1                0.0                7.1     Playoffs
# 1            7.9                7.1                0.8     Playoffs
# 2            3.5                1.4                2.2  No Playoffs
#
#       sb_winner
# 0  No Superbowl
# 1  No Superbowl
# 2  No Superbowl

# %%
# Check last rows
nfl_data.tail(3)
# Out:
#             team  team_name  year  wins  loss  points_for  points_against  \
# 635      Seattle   Seahawks  2019    11     5         405             398
# 636  Los Angeles       Rams  2019     9     7         394             364
# 637      Arizona  Cardinals  2019     5    10         361             442
#
#      points_differential  margin_of_victory  strength_of_schedule  \
# 635                    7                0.4                   2.3
# 636                   30                1.9                   2.0
# 637                  -81               -5.1                   1.8
#
#      simple_rating  offensive_ranking  defensive_ranking     playoffs  \
# 635            2.7                2.9               -0.2     Playoffs
# 636            3.9                2.2                1.7  No Playoffs
# 637           -3.2               -0.3               -2.9  No Playoffs
#
#         sb_winner
# 635  No Superbowl
# 636  No Superbowl
# 637  No Superbowl

# %%
# Summary stats
nfl_data.describe()
# Out:
#               year        wins        loss  points_for  points_against  \
# count   638.000000  638.000000  638.000000  638.000000      638.000000
# mean   2009.528213    7.984326    7.984326  350.283699      350.283699
# std       5.757664    3.083822    3.083313   71.399067       59.546661
# min    2000.000000    0.000000    0.000000  161.000000      165.000000
# 25%    2005.000000    6.000000    6.000000  299.000000      310.000000
# 50%    2010.000000    8.000000    8.000000  348.000000      347.000000
# 75%    2014.750000   10.000000   10.000000  396.000000      391.500000
# max    2019.000000   16.000000   16.000000  606.000000      517.000000
#
#        points_differential  margin_of_victory  strength_of_schedule  \
# count           638.000000         638.000000            638.000000
# mean              0.000000          -0.001881              0.001097
# std             101.088938           6.323133              1.634369
# ...

# %%
nfl_data.to_csv('../data/nfl_data.csv', index=False)
